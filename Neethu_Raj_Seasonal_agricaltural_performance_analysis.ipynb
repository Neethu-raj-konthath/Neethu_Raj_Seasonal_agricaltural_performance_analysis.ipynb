# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the data set
df = pd.read_csv("/content/seasonal_agriculture_performance_dataset.csv")

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 3995        865.4               27.3          51.4                 6.3  ...
# 3996        947.5               29.2          85.5                 6.1  ...
# 3997         80.0               35.4          68.5                 8.6  ...
# 3998        475.0               28.2          61.7                 6.4  ...
# 3999        984.3               25.8          77.2                 5.9  ...
#
# ...

# %%
df.shape
# Out:
# (4000, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %%
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
#recover from null values
df['Rainfall_mm'] = df['Rainfall_mm'].fillna(df['Rainfall_mm'].median())

df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(df['Soil_Moisture_pct'].median())

df['Yield_Tonnes_Ha'] = df['Yield_Tonnes_Ha'].fillna(df['Yield_Tonnes_Ha'].median())

# %%
df.isnull().sum()
# Out:
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# Water_Efficiency_t_per_1000m3    0
# ...

# %%
df.shape
# Out:
# (4000, 28)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Histogram chart for each Column
df.hist(bins=10, figsize = (18,18))
# Out:
# array([[<Axes: title={'center': 'Farm_Area_Hectares'}>,
#         <Axes: title={'center': 'Rainfall_mm'}>,
#         <Axes: title={'center': 'Avg_Temperature_C'}>,
#         <Axes: title={'center': 'Humidity_pct'}>,
#         <Axes: title={'center': 'Sunlight_Hours_Day'}>],
#        [<Axes: title={'center': 'Soil_pH'}>,
#         <Axes: title={'center': 'Soil_Moisture_pct'}>,
#         <Axes: title={'center': 'Nitrogen_kg_ha'}>,
#         <Axes: title={'center': 'Phosphorus_kg_ha'}>,
#         <Axes: title={'center': 'Potassium_kg_ha'}>],
#        [<Axes: title={'center': 'Fertilizer_kg_ha'}>,
#         <Axes: title={'center': 'Pesticide_Litre_ha'}>,
#         <Axes: title={'center': 'Seed_Quality_Score'}>,
#         <Axes: title={'center': 'Yield_Tonnes_Ha'}>,
#         <Axes: title={'center': 'Production_Tonnes'}>],
#        [<Axes: title={'center': 'Market_Price_INR_Tonne'}>,
#         <Axes: title={'center': 'Total_Cost_INR'}>,
#         <Axes: title={'center': 'Revenue_INR'}>,
# ...

# %%
df.groupby('Season')['Yield_Tonnes_Ha'].mean()
# Out:
# Season
# Kharif    5.628612
# Rabi      5.039435
# Zaid      4.641313
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
#Seasonal patterns
season_pattern = df.groupby('Season')[
['Yield_Tonnes_Ha',
 'Rainfall_mm',
 'Avg_Temperature_C',
 'Humidity_pct',
 'Soil_Moisture_pct',
 'Production_Tonnes',
 'Profit_INR']
].mean()
season_pattern
# Out:
#         Yield_Tonnes_Ha  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Season
# Kharif         5.628612   849.199663          28.454019     71.812591
# Rabi           5.039435   437.615366          23.489183     57.893178
# Zaid           4.641313   304.654714          31.042088     52.012121
#
#         Soil_Moisture_pct  Production_Tonnes     Profit_INR
# Season
# Kharif          31.149859          46.311192  178914.647555
# Rabi            24.069392          41.486712   87689.470191
# Zaid            19.279630          38.886111  -24804.824916

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Season', y='Yield_Tonnes_Ha', data=df)
plt.title('Agriculture Performance Across Seasons')
plt.xlabel('Season')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
season_pattern['Yield_Tonnes_Ha'].plot(kind='bar', figsize=(5,5))
plt.title('Seasonal Patterns of Yield')
plt.xlabel('Season')
plt.ylabel('Yield (Tonnes/Ha')
plt.show()

# %%
df.groupby('Season')[
['Rainfall_mm',
 'Avg_Temperature_C',
 'Humidity_pct',
 'Soil_Moisture_pct']
].mean()
# Out:
#         Rainfall_mm  Avg_Temperature_C  Humidity_pct  Soil_Moisture_pct
# Season
# Kharif   849.199663          28.454019     71.812591          31.149859
# Rabi     437.615366          23.489183     57.893178          24.069392
# Zaid     304.654714          31.042088     52.012121          19.279630

# %%
df.groupby('Season')['Fertilizer_kg_ha'].mean()
# Out:
# Season
# Kharif    187.077965
# Rabi      185.407068
# Zaid      184.638047
# Name: Fertilizer_kg_ha, dtype: float64

# %%
df.groupby('Season')['Pesticide_Litre_ha'].mean()
# Out:
# Season
# Kharif    5.079747
# Rabi      5.024690
# Zaid      5.171212
# Name: Pesticide_Litre_ha, dtype: float64

# %%
#nutrients
df.groupby('Season')[
['Nitrogen_kg_ha',
 'Phosphorus_kg_ha',
 'Potassium_kg_ha']
].mean()
# Out:
#         Nitrogen_kg_ha  Phosphorus_kg_ha  Potassium_kg_ha
# Season
# Kharif      120.020124         58.096515       105.303485
# Rabi        120.402827         57.311002       103.926060
# Zaid        120.525421         58.129125       105.416835

# %%
resource= df.groupby('Season')[
['Fertilizer_kg_ha',
 'Pesticide_Litre_ha',
 'Water_Used_m3']
].mean()
resource.plot(kind='bar', figsize=(8,8))
plt.title('Resource Usage Across Seasons')
plt.xlabel('Season')
plt.ylabel('Resource Usage (kg/ha)')
plt.show()

# %%
#Rainfall vs Yield
df[['Rainfall_mm', 'Yield_Tonnes_Ha']].corr()
# Out:
#                  Rainfall_mm  Yield_Tonnes_Ha
# Rainfall_mm         1.000000         0.030951
# Yield_Tonnes_Ha     0.030951         1.000000

# %%
sns.scatterplot(x='Rainfall_mm', y='Yield_Tonnes_Ha', data=df)
plt.title('Rainfall vs Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
# Soil moisture vs Yield
df[['Soil_Moisture_pct', 'Yield_Tonnes_Ha']].corr()
# Out:
#                    Soil_Moisture_pct  Yield_Tonnes_Ha
# Soil_Moisture_pct           1.000000         0.010999
# Yield_Tonnes_Ha             0.010999         1.000000

# %%
sns.scatterplot(x='Soil_Moisture_pct', y='Yield_Tonnes_Ha', data=df)
plt.title('Soil Moisture vs Yield')
plt.xlabel('Soil Moisture (%)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
# Temperature vs Yield
df[['Avg_Temperature_C', 'Yield_Tonnes_Ha']].corr()
# Out:
#                    Avg_Temperature_C  Yield_Tonnes_Ha
# Avg_Temperature_C           1.000000         0.009996
# Yield_Tonnes_Ha             0.009996         1.000000

# %%
sns.scatterplot(x='Avg_Temperature_C', y='Yield_Tonnes_Ha', data=df)
plt.title('Temperature vs Yield')
plt.xlabel('Temperature (°C)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
df.groupby('Season')['Revenue_INR'].mean()
# Out:
# Season
# Kharif    710719.055649
# Rabi      601526.048556
# Zaid      519171.904040
# Name: Revenue_INR, dtype: float64

# %%
df.groupby('Season')['Profit_INR'].mean()
# Out:
# Season
# Kharif    178914.647555
# Rabi       87689.470191
# Zaid      -24804.824916
# Name: Profit_INR, dtype: float64

# %%
df.groupby('Season')['Total_Cost_INR'].mean().sort_values(ascending=False)
# Out:
# Season
# Zaid      543976.728956
# Kharif    531804.408094
# Rabi      513836.578365
# Name: Total_Cost_INR, dtype: float64

# %%
sns.barplot(x='Season', y='Profit_INR', data=df)
plt.title('Average Profit Across Seasons')
plt.xlabel('Season')
plt.ylabel('Average Profit (INR)')
plt.show()

# %%
# Seasonal patterns across different regions
#by state
state = df.groupby(['State','Season'])['Yield_Tonnes_Ha'].mean()
state
# Out:
# State           Season
# Andhra Pradesh  Kharif    5.676958
#                 Rabi      3.470931
#                 Zaid      4.448000
# Gujarat         Kharif    6.338416
#                 Rabi      5.441700
#                 Zaid      4.066716
# Karnataka       Kharif    6.455024
#                 Rabi      4.567864
#                 Zaid      6.623243
# Madhya Pradesh  Kharif    5.985265
#                 Rabi      3.760385
#                 Zaid      5.478889
# Maharashtra     Kharif    5.430315
#                 Rabi      5.501927
#                 Zaid      2.277778
# Punjab          Kharif    4.100633
#                 Rabi      8.609355
#                 Zaid      5.909610
# Tamil Nadu      Kharif    5.520534
#                 Rabi      4.501394
#                 Zaid      4.097746
# Telangana       Kharif    5.552436
#                 Rabi      4.784569
#                 Zaid      4.248471
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
pd.pivot_table(df, values='Yield_Tonnes_Ha', index='State', columns='Season',aggfunc='mean')
# Out:
# Season            Kharif      Rabi      Zaid
# State
# Andhra Pradesh  5.676958  3.470931  4.448000
# Gujarat         6.338416  5.441700  4.066716
# Karnataka       6.455024  4.567864  6.623243
# Madhya Pradesh  5.985265  3.760385  5.478889
# Maharashtra     5.430315  5.501927  2.277778
# Punjab          4.100633  8.609355  5.909610
# Tamil Nadu      5.520534  4.501394  4.097746
# Telangana       5.552436  4.784569  4.248471

# %%
#differnce b/w crops in differ seasons
plt.figure(figsize=(10,6))
sns.barplot(x='Crop', y='Yield_Tonnes_Ha', hue='Season', data=df)
plt.title('Yield Across Different Seasons')
plt.xlabel('Crop')
plt.ylabel('Yield (Tonnes/Ha)')
plt.xticks(rotation=90)
plt.show()

# %%
#unusual pattern
plt.figure(figsize=(10,6))
sns.barplot(x='Season', y='Yield_Tonnes_Ha', data=df)
plt.title('Yield variation and outliers')
plt.xlabel('Season')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
# variables most related to agricultural performance
variable = df[
    ['Rainfall_mm',
     'Avg_Temperature_C',
     'Humidity_pct',
     'Sunlight_Hours_Day',
     'Soil_pH',
     'Soil_Moisture_pct',
     'Fertilizer_kg_ha',
     'Pesticide_Litre_ha',
     'Water_Used_m3',
     'Yield_Tonnes_Ha',
     'Production_Tonnes',
     'Profit_INR']
].corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(variable, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.groupby('Crop')['Yield_Tonnes_Ha'].mean().sort_values(ascending=False)
# Out:
# Crop
# Sugarcane    46.642361
# Maize         2.710036
# Rice          2.431304
# Wheat         2.108013
# Chilli        1.542767
# Groundnut     1.322901
# Cotton        1.229783
# Pulses        0.921512
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Crop', y='Yield_Tonnes_Ha')
plt.title('Average Yield by Crop')
plt.xlabel('Crop')
plt.ylabel('Yield (Tonnes/Ha)')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('Crop')['Profit_INR'].mean().sort_values(ascending=False)
# Out:
# Crop
# Sugarcane    817187.986885
# Chilli       750878.342233
# Cotton       124546.915354
# Groundnut     44858.120283
# Pulses        -4238.052419
# Maize        -83978.326679
# Rice        -102213.504348
# Wheat       -123398.337134
# Name: Profit_INR, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Crop', y='Profit_INR')
plt.title('Average Profit by Crop')
plt.xlabel('Crop')
plt.ylabel('Profit (INR)')
plt.xticks(rotation=45)
plt.show()

# %%
df[['Fertilizer_kg_ha', 'Yield_Tonnes_Ha']].corr()
# Out:
#                   Fertilizer_kg_ha  Yield_Tonnes_Ha
# Fertilizer_kg_ha          1.000000         0.000018
# Yield_Tonnes_Ha           0.000018         1.000000

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=df,
    x='Fertilizer_kg_ha',
    y='Yield_Tonnes_Ha'
)
plt.title('Fertilizer Usage vs Crop Yield')
plt.xlabel('Fertilizer (kg/ha)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
df.groupby('Season')['Water_Efficiency_t_per_1000m3'].mean().sort_values(ascending=False)
# Out:
# Season
# Kharif    5.891834
# Rabi      5.186122
# Zaid      4.413239
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    data=df,
    x='Season',
    y='Water_Efficiency_t_per_1000m3'
)
plt.title('Water Efficiency Across Seasons')
plt.xlabel('Season')
plt.ylabel('Water Efficiency')
plt.show()

# %%
df[['Soil_pH', 'Yield_Tonnes_Ha']].corr()
# Out:
#                   Soil_pH  Yield_Tonnes_Ha
# Soil_pH          1.000000        -0.020672
# Yield_Tonnes_Ha -0.020672         1.000000

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=df,
    x='Soil_pH',
    y='Yield_Tonnes_Ha'
)
plt.title('Soil pH vs Crop Yield')
plt.xlabel('Soil pH')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
df.groupby('Season')['Disease_Pest_Risk_pct'].mean().sort_values(ascending=False)
# Out:
# Season
# Kharif    54.467903
# Rabi      40.482114
# Zaid      38.216667
# Name: Disease_Pest_Risk_pct, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=df,
    x='Season',
    y='Disease_Pest_Risk_pct'
)
plt.title('Disease and Pest Risk Across Seasons')
plt.xlabel('Season')
plt.ylabel('Disease/Pest Risk (%)')
plt.show()

# %%
df.groupby('Crop')['Water_Efficiency_t_per_1000m3'].mean().sort_values(ascending=False)
# Out:
# Crop
# Sugarcane    30.477672
# Maize         5.602995
# Wheat         4.628393
# Groundnut     3.154795
# Chilli        2.947709
# Pulses        2.896504
# Rice          1.946112
# Cotton        1.938016
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    data=df,
    x='Crop',
    y='Water_Efficiency_t_per_1000m3'
)
plt.title('Water Efficiency by Crop')
plt.xlabel('Crop')
plt.ylabel('Water Efficiency')
plt.xticks(rotation=45)
plt.show()
